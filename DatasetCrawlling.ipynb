# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

# %% [markdown]
# <h1>멜론 1개월 기준 많이 들은 음악 크롤링</h1>

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)
driver.get('https://www.melon.com/')

isLogin = driver.find_element_by_class_name('btn_login')

try:
    if isLogin:
    #     PH = input("멜론 아이디 : ")
        ID = 'jq3210'

    #     PW = input("비밀번호 : ")
        PW = 'power900!'

        isLogin.click()
        driver.find_element_by_xpath('//*[@title="멜론아이디 로그인"]').click()

        driver.find_element_by_name('id').send_keys(ID)
        driver.find_element_by_name('pwd').send_keys(PW)

        driver.find_element_by_class_name('btn_login03').click()

        print('로그인 성공')
    else:
        print('로그인 실패')

    driver.find_element_by_link_text('마이뮤직').click()
    driver.find_element_by_link_text('많이 들은').click()
    driver.find_element_by_link_text('1개월').click()
    time.sleep(0.5)

    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    trs = soup.select('tr')
    d = {}
    lidx = []
    ltitle = []
    lartist = []
    lgenre = []
    lgood = []
    for idx,tr in enumerate(trs[1:]):
        #장르 확인
        driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr[{}]/td[3]/div/div/a[1]/span'.format(idx+1)).click()
        genre = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]').text
        
        driver.back()
        driver.find_element_by_link_text('1개월').click()
        time.sleep(0.5)
        
        title = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[3]/div/div/a[2]'.format(idx+1)).text.strip()
        artist = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[4]/div/div/a'.format(idx+1)).text.strip()
        good = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[6]/div/button/span[2]'.format(idx+1)).text.strip()
        good = int(good.replace(',',''))
        
        lidx.append(idx+1)        #순번
        ltitle.append(title)      #제목
        lartist.append(artist)    #가수
        lgenre.append(genre)      #장르
        lgood.append(good)        #좋아요

    d['no'] = lidx
    d['title'] = ltitle
    d['artist'] = lartist
    d['genre'] = lgenre
    d['good'] = lgood
    
    column = ['no','title','artist','genre','good']
    df = pd.DataFrame(d,columns = column)
except Exception as e:
    print(e)
finally:
    driver.quit()
    print('driver.quit() 완료')
# Out:
# 로그인 성공
# driver.quit() 완료

# %%
df.set_index('no',inplace=True)
df
# Out:
#                                                 title                 artist  \
# no
# 1                                           Pretender  Official Hige Dandism
# 2                                                 여우비                   제이워크
# 3                                            Marigold                 Aimyon
# 4                                            Harunohi                 Aimyon
# 5                                                  희재                    성시경
# 6                                                 반창고                    MC몽
# 7                                              마지막 인사                BIGBANG
# 8                                                 신호등                    이무진
# 9                                               문어의 꿈                    안예은
# 10                                     삐딱하게 (Crooked)               G-DRAGON
# 11  君はロックを聽かない / Kimiwa Rock Wo Kikanai (너는 록을 듣지 않아)                 Aimyon
# 12                                            사랑은 타이밍                버스커 버스커
# 13             So Fresh (Feat. 김태우) (위대한 캣츠비 OST 삽입곡)                    MC몽
# 14                                               해바라기            윤하 (YOUNHA)
# 15                                    추억은 만남보다 이별에 남아                    정동하
# 16                          내 생애 가장 행복한 시간 (Feat. 허각)                    MC몽
# 17                                    있잖아 (Rock Ver.)                    아이유
# 18                                                 고백                    장범준
# 19                                                 회상                    장범준
# 20             I Love U Oh Thank U (Feat. 김태우 Of God)                    MC몽
# 21                                              그때 우리                   우주소녀
# 22                                               알았다면                    장덕철
# 23                                    너만이 (Feat. 헤이즈)                    유승우
# 24                                        Hello Hello      FTISLAND (FT아일랜드)
# 25                                        Bubble Love                    MC몽
# 26                                  못된 영화 (Feat. IVY)                    MC몽
# 27                                     OHAYO MY NIGHT            디핵 (D-Hack)
# 28                                               있어줘요                    장덕철
# 29                                                U R           태연 (TAEYEON)
# 30                                   프라프치노 (Feat. 팀버)                   제이워크
# 31                                너에게 쓰는 편지 (Feat. 린)                    MC몽
# 32                                            빛이 되어줄게            윤하 (YOUNHA)
# 33                                      희망 (Original)                    박세아
# 34                                          Monologue                     버즈
# 35                                            듣고 싶던 말                     허각
# 36                                              우리의 꿈                    코요태
# 37                                               그날처럼                    장덕철
# 38                                          Butterfly                  러브홀릭스
# 39                                             Always                     신지
# 40                                    눈치없긴 (Feat. 유주)                  San E
# 41                사랑한다 외쳐요 (Feat. 미료 From 브라운 아이드 걸스)                   제이워크
# 42                                            아름다운 구속                    김종서
# 43                              죽을 만큼 아파서 (Feat. 멜로우)                    MC몽
# 44                                              5월의 밤                 Zion.T
# 45                                            BAD BOY                BIGBANG
# 46                                               사랑먼지                BIGBANG
# 47                                          LOVE SONG                BIGBANG
# 48                                              하루 하루                BIGBANG
# 49                                            한번 더 이별                    성시경
# 50                                           Suddenly                   제이워크
#
#          genre    good
# no
# 1        J-POP    9690
# 2          발라드   15089
# 3        J-POP    5234
# 4        J-POP    3665
# 5    발라드, 국내영화   88868
# 6         랩/힙합   23110
# 7     댄스, 랩/힙합   50205
# 8         록/메탈  151119
# 9           댄스   17251
# 10        랩/힙합  134309
# 11       J-POP    6233
# 12        록/메탈   61047
# 13        랩/힙합   20907
# 14        록/메탈    1910
# 15         발라드   53325
# 16        랩/힙합   85493
# 17          댄스   42864
# 18        록/메탈   16364
# 19  발라드, 국내드라마   56076
# 20        랩/힙합   36217
# 21          댄스    7290
# 22         발라드   48146
# 23   발라드, 인디음악   42597
# 24        록/메탈    9923
# 25         발라드   44804
# 26        랩/힙합    2037
# 27        랩/힙합   77176
# 28   발라드, 인디음악   79253
# 29         발라드  120375
# 30         발라드    9376
# 31        랩/힙합   75075
# 32  발라드, 국내드라마   12598
# 33          게임    6491
# 34        록/메탈   51448
# 35         발라드   15340
# 36        록/메탈   15062
# 37         발라드  238297
# 38        국내영화   42112
# 39      댄스, 게임    9690
# 40        랩/힙합    6713
# 41          댄스    3496
# 42        록/메탈   10503
# 43        랩/힙합   81128
# 44         발라드   45166
# 45         발라드   68192
# 46          댄스   36526
# 47          댄스   43999
# 48    댄스, 랩/힙합   79160
# 49         발라드   37263
# 50         발라드   16185

# %%
df.to_csv('myMusic.csv')
