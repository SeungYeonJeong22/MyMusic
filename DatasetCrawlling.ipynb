# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

# %% [markdown]
# <h1>멜론 1개월 기준 많이 들은 음악 크롤링</h1>

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)
driver.get('https://www.melon.com/')

isLogin = driver.find_element_by_class_name('btn_login')

try:
    if isLogin:
    #     PH = input("멜론 아이디 : ")
        ID = 'jq3210'

    #     PW = input("비밀번호 : ")
        PW = 'power900!'

        isLogin.click()
        driver.find_element_by_xpath('//*[@title="멜론아이디 로그인"]').click()

        driver.find_element_by_name('id').send_keys(ID)
        driver.find_element_by_name('pwd').send_keys(PW)

        driver.find_element_by_class_name('btn_login03').click()

        print('로그인 성공')
    else:
        print('로그인 실패')

    driver.find_element_by_link_text('마이뮤직').click()
    driver.find_element_by_link_text('많이 들은').click()
    driver.find_element_by_link_text('1개월').click()
    time.sleep(0.5)

    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    trs = soup.select('tr')
    d = {}
    lidx = []
    ltitle = []
    lartist = []
    lgenre = []
    lgood = []
    for idx,tr in enumerate(trs[1:]):
        #장르 확인
        driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr[{}]/td[3]/div/div/a[1]/span'.format(idx+1)).click()
        genre = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]').text
        
        driver.back()
        driver.find_element_by_link_text('1개월').click()
        time.sleep(0.5)
        
        title = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[3]/div/div/a[2]'.format(idx+1)).text.strip()
        artist = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[4]/div/div/a'.format(idx+1)).text.strip()
        good = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[6]/div/button/span[2]'.format(idx+1)).text.strip()
        good = int(good.replace(',',''))
        
        lidx.append(idx+1)        #순번
        ltitle.append(title)      #제목
        lartist.append(artist)    #가수
        lgenre.append(genre)      #장르
        lgood.append(good)        #좋아요

    d['no'] = lidx
    d['title'] = ltitle
    d['artist'] = lartist
    d['genre'] = lgenre
    d['good'] = lgood
    
    column = ['no','title','artist','genre','good']
    df = pd.DataFrame(d,columns = column)
except Exception as e:
    print(e)
finally:
    driver.quit()
    print('driver.quit() 완료')
# Out:
# 로그인 성공
# driver.quit() 완료

# %%
df.set_index('no',inplace=True)
df
# Out:
#                                                 title                 artist  \
# no
# 1                                           Butterfly                  러브홀릭스
# 2                                               비와 당신                   럼블피쉬
# 3                                           Pretender  Official Hige Dandism
# 4                                             듣고 싶던 말                     허각
# 5                                              마지막 인사                BIGBANG
# 6                                                 신호등                    이무진
# 7                                            Marigold                 Aimyon
# 8                                               문어의 꿈                    안예은
# 9                                     추억은 만남보다 이별에 남아                    정동하
# 10                                           Harunohi                 Aimyon
# 11                                     삐딱하게 (Crooked)               G-DRAGON
# 12                                                 희재                    성시경
# 13                                               알았다면                    장덕철
# 14                                               있어줘요                    장덕철
# 15  君はロックを聽かない / Kimiwa Rock Wo Kikanai (너는 록을 듣지 않아)                 Aimyon
# 16                                    있잖아 (Rock Ver.)                    아이유
# 17                                             Always                     신지
# 18                                              그때 우리                   우주소녀
# 19                                    너만이 (Feat. 헤이즈)                    유승우
# 20                                        Hello Hello      FTISLAND (FT아일랜드)
# 21                                      희망 (Original)                    박세아
# 22                                            사랑은 타이밍                버스커 버스커
# 23                                              우리의 꿈                    코요태
# 24                                               그날처럼                    장덕철
# 25                                                U R           태연 (TAEYEON)
# 26                                                 고백                    장범준
# 27                                                 회상                    장범준
# 28                                            아름다운 구속                    김종서
# 29                                     OHAYO MY NIGHT            디핵 (D-Hack)
# 30                                              5월의 밤                 Zion.T
# 31                                            BAD BOY                BIGBANG
# 32                                               사랑먼지                BIGBANG
# 33                                          LOVE SONG                BIGBANG
# 34                                      기억하니? (Inst.)                   July
# 35                                            Someday                    아이유
# 36                                              하루 하루                BIGBANG
# 37                                            한번 더 이별                    성시경
# 38                            지금 말해볼게요 (낮에 뜨는 달 X 거미)                     거미
# 39                                       다시 사랑할 수 있을까                    백지영
# 40                                            나는 너 좋아                    장범준
# 41                                           나를 아는 사람           MSG워너비(정상동기)
# 42                                              넌 내꺼야                     경서
# 43     Till I Know What Love Is (I'm Never Gonna Die)                 Aimyon
# 44                                        Naked Heart                 Aimyon
# 45  I See the Light (From "Tangled" / Soundtrack V...            Mandy Moore
# 46                                                거짓말                BIGBANG
# 47                                 Grip! (이누야샤 4기 OP)     Every Little Thing
#
#                     genre    good
# no
# 1                    국내영화   41485
# 2                     발라드   70503
# 3                   J-POP    9526
# 4                     발라드   15306
# 5                댄스, 랩/힙합   50083
# 6                    록/메탈  137454
# 7                   J-POP    5164
# 8                      댄스   15988
# 9                     발라드   51987
# 10                  J-POP    3629
# 11                   랩/힙합  134037
# 12              발라드, 국내영화   88546
# 13                    발라드   48092
# 14              발라드, 인디음악   79130
# 15                  J-POP    6130
# 16                     댄스   42743
# 17                 댄스, 게임    9658
# 18                     댄스    7268
# 19              발라드, 인디음악   42557
# 20                   록/메탈    9901
# 21                     게임    6459
# 22                   록/메탈   60997
# 23                   록/메탈   14890
# 24                    발라드  238132
# 25                    발라드  120011
# 26                   록/메탈   14151
# 27             발라드, 국내드라마   56018
# 28                   록/메탈   10479
# 29                   랩/힙합   67713
# 30                    발라드   45095
# 31                    발라드   68091
# 32                     댄스   36482
# 33                     댄스   43916
# 34             랩/힙합, 인디음악     529
# 35             발라드, 국내드라마   78200
# 36               댄스, 랩/힙합   78904
# 37                    발라드   36943
# 38                    발라드    5678
# 39                    발라드   12691
# 40            록/메탈, 국내드라마   14728
# 41                    발라드   64846
# 42                    발라드    4211
# 43                  J-POP     693
# 44                  J-POP    2318
# 45  POP, 애니메이션/웹툰, 키즈, 만화   41599
# 46               댄스, 랩/힙합   76931
# 47        애니메이션/웹툰, J-POP    1503

# %%
df.to_csv('myMusic.csv')
