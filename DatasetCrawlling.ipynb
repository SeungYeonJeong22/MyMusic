# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

# %% [markdown]
# <h1>멜론 1개월 기준 많이 들은 음악 크롤링</h1>

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)
driver.get('https://www.melon.com/')

isLogin = driver.find_element_by_class_name('btn_login')

try:
    if isLogin:
    #     PH = input("멜론 아이디 : ")
        ID = 'jq3210'

    #     PW = input("비밀번호 : ")
        PW = 'power900!'

        isLogin.click()
        driver.find_element_by_xpath('//*[@title="멜론아이디 로그인"]').click()

        driver.find_element_by_name('id').send_keys(ID)
        driver.find_element_by_name('pwd').send_keys(PW)

        driver.find_element_by_class_name('btn_login03').click()

        print('로그인 성공')
    else:
        print('로그인 실패')

    driver.find_element_by_link_text('마이뮤직').click()
    driver.find_element_by_link_text('많이 들은').click()
    driver.find_element_by_link_text('1개월').click()
    time.sleep(0.5)

    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    trs = soup.select('tr')
    d = {}
    lidx = []
    ltitle = []
    lartist = []
    lgenre = []
    lgood = []
    for idx,tr in enumerate(trs[1:]):
        #장르 확인
        driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr[{}]/td[3]/div/div/a[1]/span'.format(idx+1)).click()
        genre = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]').text
        
        driver.back()
        driver.find_element_by_link_text('1개월').click()
        time.sleep(0.5)
        
        title = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[3]/div/div/a[2]'.format(idx+1)).text.strip()
        artist = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[4]/div/div/a'.format(idx+1)).text.strip()
        good = driver.find_element_by_xpath('//html/body/div/div[2]/div/div/div[3]/form/div/table/tbody/tr[{}]/td[6]/div/button/span[2]'.format(idx+1)).text.strip()
        good = int(good.replace(',',''))
        
        lidx.append(idx+1)        #순번
        ltitle.append(title)      #제목
        lartist.append(artist)    #가수
        lgenre.append(genre)      #장르
        lgood.append(good)        #좋아요

    d['no'] = lidx
    d['title'] = ltitle
    d['artist'] = lartist
    d['genre'] = lgenre
    d['good'] = lgood
    
    column = ['no','title','artist','genre','good']
    df = pd.DataFrame(d,columns = column)
except Exception as e:
    print(e)
finally:
    driver.quit()
    print('driver.quit() 완료')
# Out:
# 로그인 성공
# driver.quit() 완료

# %%
df.set_index('no',inplace=True)
df
# Out:
#                                                 title                 artist  \
# no
# 1                                          TWINTAIL20            디핵 (D-Hack)
# 2                                                 여우비                   제이워크
# 3                                                 반창고                    MC몽
# 4                                           Pretender  Official Hige Dandism
# 5                                      OHAYO MY NIGHT            디핵 (D-Hack)
# 6                                     눈치없긴 (Feat. 유주)                  San E
# 7                                            Marigold                 Aimyon
# 8              So Fresh (Feat. 김태우) (위대한 캣츠비 OST 삽입곡)                    MC몽
# 9                                                  희재                    성시경
# 10                          내 생애 가장 행복한 시간 (Feat. 허각)                    MC몽
# 11                                   프라프치노 (Feat. 팀버)                   제이워크
# 12                                            요즘 너 말야         제이레빗(J Rabbit)
# 13             I Love U Oh Thank U (Feat. 김태우 Of God)                    MC몽
# 14                                           Harunohi                 Aimyon
# 15                                  못된 영화 (Feat. IVY)                    MC몽
# 16                                            사랑은 타이밍                버스커 버스커
# 17                                        Bubble Love                    MC몽
# 18                                별과 꿈의 이야기(Feat.한요한)            디핵 (D-Hack)
# 19  君はロックを聽かない / Kimiwa Rock Wo Kikanai (너는 록을 듣지 않아)                 Aimyon
# 20                                                 고백                    장범준
# 21                                                 회상                    장범준
# 22                                너에게 쓰는 편지 (Feat. 린)                    MC몽
# 23                                               해바라기            윤하 (YOUNHA)
# 24                                                신호등                    이무진
# 25                                    너만이 (Feat. 헤이즈)                    유승우
# 26                              첫사랑 ('응답하라 1994' 삽입곡)                  써니사이드
# 27                                              문어의 꿈                    안예은
# 28                너와 나의 아르카디아(Feat.마호 of Adios audio)            디핵 (D-Hack)
# 29                                              그때 우리                   우주소녀
# 30                                                U R           태연 (TAEYEON)
# 31                            TADAIMA(Feat.Cloudybay)            디핵 (D-Hack)
# 32            나는 내일 과거의 너와 만난다 (Feat. 김미정 yourbeagle)            디핵 (D-Hack)
# 33                                        Hello Hello      FTISLAND (FT아일랜드)
# 34                                    있잖아 (Rock Ver.)                    아이유
# 35                                             마지막 인사                BIGBANG
# 36                      우리들이 있었다 (Feat. Skinny Brown)            디핵 (D-Hack)
# 37                                            빛이 되어줄게            윤하 (YOUNHA)
# 38                                          Monologue                     버즈
# 39                                          헤어지는 중입니다                    이은미
# 40                                     삐딱하게 (Crooked)               G-DRAGON
# 41                사랑한다 외쳐요 (Feat. 미료 From 브라운 아이드 걸스)                   제이워크
# 42                                    추억은 만남보다 이별에 남아                    정동하
# 43                                               알았다면                    장덕철
# 44                                               있어줘요                    장덕철
# 45                              죽을 만큼 아파서 (Feat. 멜로우)                    MC몽
# 46                                              5월의 밤                 Zion.T
# 47                                            한번 더 이별                    성시경
# 48                                           Suddenly                   제이워크
# 49                                              아마...                   제이워크
# 50                                            아름다운 구속                    김종서
#
#            genre    good
# no
# 1           랩/힙합   17393
# 2            발라드   15105
# 3           랩/힙합   23147
# 4          J-POP    9814
# 5           랩/힙합   85027
# 6           랩/힙합    7691
# 7          J-POP    5272
# 8           랩/힙합   20930
# 9      발라드, 국내영화   89143
# 10          랩/힙합   85614
# 11           발라드    9376
# 12  인디음악, 포크/블루스   68095
# 13          랩/힙합   36300
# 14         J-POP    3690
# 15          랩/힙합    2036
# 16          록/메탈   61081
# 17           발라드   44900
# 18          랩/힙합    9709
# 19         J-POP    6305
# 20          록/메탈   18526
# 21    발라드, 국내드라마   56126
# 22          랩/힙합   75210
# 23          록/메탈    1911
# 24          록/메탈  161752
# 25     발라드, 인디음악   42626
# 26           발라드   28243
# 27            댄스   18186
# 28          랩/힙합    3103
# 29            댄스    7302
# 30           발라드  120604
# 31          랩/힙합    2155
# 32          랩/힙합    5509
# 33          록/메탈    9950
# 34            댄스   42972
# 35      댄스, 랩/힙합   50305
# 36          랩/힙합    6105
# 37    발라드, 국내드라마   12613
# 38          록/메탈   51545
# 39           발라드    1835
# 40          랩/힙합  134538
# 41            댄스    3503
# 42           발라드   54263
# 43           발라드   48187
# 44     발라드, 인디음악   79328
# 45          랩/힙합   81313
# 46           발라드   45243
# 47           발라드   37420
# 48           발라드   16192
# 49            댄스    2824
# 50          록/메탈   10517

# %%
df.to_csv('myMusic.csv',encoding='utf-8 sig')
