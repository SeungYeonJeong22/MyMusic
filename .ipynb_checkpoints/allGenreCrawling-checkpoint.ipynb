# %% [markdown]
# <h1>전체 장르 다듬기</h1>

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)
driver.get('https://www.melon.com/')


try:
    driver.find_element_by_link_text('장르 음악').click()
    time.sleep(0.5)

    Category = driver.find_element_by_xpath('//*[@id="gnb_menu"]/ul[1]/li[3]/div/ul').text.split('\n')
    Category = [Category for Category in Category]
    
    all_genre = []
    
    for cat in Category:
        driver.find_element_by_link_text(cat).click()
    
        genre = driver.find_element_by_xpath('//*[@id="conts"]/div[2]/ul').text.split('\n')
        genre_category = [genre for genre in genre]
        for g in genre_category:
            all_genre.append(g)

        for genre_sub in genre_category:
            driver.find_element_by_link_text(genre_sub).click()

            try:
                if driver.find_element_by_class_name("wrap_tabmenu_sub"):
                    sub_genre = driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul').text.split('\n')

                    sub_genre = [sub_genre for sub_genre in sub_genre]
                    for i in sub_genre:
                        all_genre.append(i)
            except:
                continue

        while "세부장르전체" in all_genre:
            all_genre.remove('세부장르전체')

    all_genre = list(set(all_genre))
    print(all_genre)

except Exception as e:
    print(e)
finally:
    driver.quit()
    print('driver.quit() 완료')
# Out:
# ['만화', '국외뮤지컬', '갱스터/하드코어랩', '자장가', '불교음악', 'J-Newage', '얼터너티브팝', '태교', 'OST', '국외드라마', '성악/합창곡', '포크/블루스/컨트리', '켈틱/아이리시', 'CCM', '오페라', '뽕짝트로트', '록/메탈', 'East&West', '랩/힙합', '어린이클래식', '현대음악', '포크/블루스', '시대별 작곡가', '민요', '클럽뮤직', '신세대트로트', '하우스', '교과서동요', '전래동요', '찬송가', '라틴', '명작동화', '팝랩', '레게', '교향곡', '어린이', '국내영화', '월드팝', '월드뮤직', '애니메이션/게임', '연주곡', '포크', '협주곡', '영어동화', 'R&B', '라틴재즈', '영어동요', '트로트메들리', '댄스', '하드록', '록스타일', '보사노바', '국악가요', '풍물/사물놀이', 'POP', '뉴에이지피아노', 'J-Jazz', '뉴에이지', '일렉트로니카', '뉴에이지기타', '국악', '중국음악', '관현악', '국내뮤지컬', '전설의트로트', '빅밴드/스윙', '클래식', '브라질', '블루스', 'J-POP', '보컬재즈', '종교음악', '포스트록', 'Soul', '국내드라마', '파두', '샹송', '트로트', '재즈', '이지리스닝', '크로스오버', '애시드/팝재즈', '일렉트로닉스타일', '발레/무용곡', '프로그레시브/아트록', 'R&B/Soul', '컨트리', '국외CCM', '창작동요', '얼터너티브록', '판소리/단가', '국외영화', 'Urban', '독주곡', '시부야케이', '어린이/태교', '국내CCM', '뉴메탈/하드코어', '인디음악', '창작동화', '기능성음악', '발라드', '올디스', '록', '가톨릭음악', '헤비메탈', '칸초네', '어쿠스틱스타일', '모던록', '얼터너티브힙합', '탱고/플라멩코', '성가', '실내악', 'Bop', '언더그라운드힙합', '워십']
# driver.quit() 완료

# %%
column = ['장르']
all_genre_df = pd.DataFrame(all_genre,columns=column)
# all_genre_df.set_index('장르',inplace=True)
all_genre_df.to_csv('allGenre.csv')

# %% [markdown]
# <h1>최신 곡</h1><br>
# 여기서 이제 곡 추천해줄 예정

# %%
# options = webdriver.ChromeOptions()
# driver = webdriver.Chrome('./chromedriver')
# driver.implicitly_wait(2)
# driver.get('https://www.melon.com/')

# try:
#     driver.find_element_by_link_text('최신 음악').click()
#     time.sleep(0.2)
    
#     html = driver.page_source
#     soup = BeautifulSoup(html,'html.parser')
    
#     trs = soup.select('tr')
#     d = {}
    
#     lsong_no = []
#     lsong_title = []
#     lsong_artist = []
#     lsong_genre = []
#     lsong_good = []
    
#     no = 0
#     for i in range(1,5):
#         for idx,tr in enumerate(trs[1:]):
#             driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr[{}]/td[4]/div/a'.format(idx+1)).click()

#             song_genre = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]').text
#             song_good = driver.find_element_by_id('d_like_count').text

#             driver.back()

#             song_title = tr.select('a')[2].text.strip()
#             song_artist = tr.select('a')[3].text.strip()

#             lsong_no.append(no+1)
#             lsong_title.append(song_title)
#             lsong_artist.append(song_artist)
#             lsong_genre.append(song_genre)
#             lsong_good.append(song_good)
            
#             no += 1
            
#         driver.find_element_by_xpath('//*[@id="pageObjNavgation"]/div/span/a[{}]'.format(i)).click()
#         time.sleep(0.5)
    
#     d['no']        = lsong_no
#     d['title']     = lsong_title
#     d['artist']    = lsong_artist
#     d['genre']     = lsong_genre
#     d['good']      = lsong_good

#     column = ['no','title','artist','genre','good']
#     df = pd.DataFrame(d,columns = column)
#     df.set_index('no',inplace = True)

# except Exception as e:
#     print(e)
# #     continue
# finally:
#     driver.quit()
#     print('driver.quit() 완료')
# Out:
# driver.quit() 완료

# %%
# df
# Out:
#                     title          artist         genre good
# no
# 1                     내 옆        SURL (설)    인디음악, 록/메탈  327
# 2                   흔한 후회            JERO    발라드, 국내드라마   22
# 3                   뭐, 그냥              몽니    인디음악, 록/메탈   57
# 4                  Salute    unknown zone          랩/힙합    5
# 5           My Everything             공민지           발라드   10
# ..                    ...             ...           ...  ...
# 196              널 잊지 못했어     비비안 (BBAHN)    발라드, 국내드라마   72
# 197         그렇게 아팠던 시간 지나            어반폴리           발라드   90
# 198             BABY GIRL    미카엘 (M!KYLE)  인디음악, 일렉트로니카  243
# 199           smokes on !       yellowism           발라드   39
# 200  벌꿀오소리 (Honey Badger)  썬더스 (Thunders)    발라드, 국내드라마   42
#
# [200 rows x 4 columns]
