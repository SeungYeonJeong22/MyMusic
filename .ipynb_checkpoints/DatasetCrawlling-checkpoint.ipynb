# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

# %% [markdown]
# <h1>멜론 1개월 기준 많이 들은 음악 크롤링</h1>

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)
driver.get('https://www.melon.com/')

isLogin = driver.find_element_by_class_name('btn_login')

try:
    if isLogin:
    #     PH = input("멜론 아이디 : ")
        ID = 'jq3210'

    #     PW = input("비밀번호 : ")
        PW = 'power900!'

        isLogin.click()
        driver.find_element_by_xpath('//*[@title="멜론아이디 로그인"]').click()

        driver.find_element_by_name('id').send_keys(ID)
        driver.find_element_by_name('pwd').send_keys(PW)

        driver.find_element_by_class_name('btn_login03').click()

        print('로그인 성공')
    else:
        print('로그인 실패')

    driver.find_element_by_link_text('마이뮤직').click()
    driver.find_element_by_link_text('많이 들은').click()
    driver.find_element_by_link_text('1개월').click()
    time.sleep(0.5)

    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    trs = soup.select('tr')
    d = {}
    lidx = []
    ltitle = []
    lartist = []
    lgenre = []
    for idx,tr in enumerate(trs[1:]):
        #장르 확인
        driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr[{}]/td[3]/div/div/a[1]/span'.format(idx+1)).click()
        genre = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]').text
        
        driver.back()
        driver.find_element_by_link_text('1개월').click()
        time.sleep(0.5)
        
        title = tr.select('a')[1].text.strip()
        artist = tr.select('td')[3].text.strip()
        
        lidx.append(idx+1)        #순번
        ltitle.append(title)      #제목
        lartist.append(artist)    #가수
        lgenre.append(genre)      #장르

    d['no'] = lidx
    d['title'] = ltitle
    d['artist'] = lartist
    d['genre'] = lgenre
    
    column = ['no','title','artist','genre']
    df = pd.DataFrame(d,columns = column)
except Exception as e:
    print(e)
finally:
    driver.quit()
    print('driver.quit() 완료')
# Out:
# 로그인 성공
# driver.quit() 완료

# %%
df.set_index('no',inplace=True)
df
# Out:
#                                                 title  \
# no
# 1                                           Butterfly
# 2                                               비와 당신
# 3                                             듣고 싶던 말
# 4                                           Pretender
# 5                                              마지막 인사
# 6                                                 신호등
# 7                                               문어의 꿈
# 8                                     추억은 만남보다 이별에 남아
# 9                                      삐딱하게 (Crooked)
# 10                                           Harunohi
# 11                                               알았다면
# 12                                           Marigold
# 13                                               있어줘요
# 14                                    있잖아 (Rock Ver.)
# 15  君はロックを聽かない / Kimiwa Rock Wo Kikanai (너는 록을 듣지 않아)
# 16                                             Always
# 17                                              그때 우리
# 18                                    너만이 (Feat. 헤이즈)
# 19                                        Hello Hello
# 20                                      희망 (Original)
# 21                                              우리의 꿈
# 22                                               그날처럼
# 23                                                U R
# 24                                            아름다운 구속
# 25                                      기억하니? (Inst.)
# 26                                              넌 내꺼야
# 27                                            BAD BOY
# 28                                               사랑먼지
# 29                                          LOVE SONG
# 30                          기억하니? (Feat. 1Sagain, 윤진)
# 31                                            Someday
# 32                                              하루 하루
# 33                                            한번 더 이별
# 34                            지금 말해볼게요 (낮에 뜨는 달 X 거미)
# 35                                                 고백
# 36                                       다시 사랑할 수 있을까
# 37                                            나는 너 좋아
# 38                                           나를 아는 사람
# 39     Till I Know What Love Is (I'm Never Gonna Die)
# 40                                        Naked Heart
# 41                                             My Boo
# 42  I See the Light (From "Tangled" / Soundtrack V...
# 43                                                거짓말
# 44                                 Grip! (이누야샤 4기 OP)
# 45                                 If I Leave (나 가거든)
# 46                                             My Boo
#
#                        artist                  genre
# no
# 1                       러브홀릭스                   국내영화
# 2                        럼블피쉬                    발라드
# 3                          허각                    발라드
# 4       Official Hige Dandism                  J-POP
# 5                     BIGBANG               댄스, 랩/힙합
# 6                         이무진                   록/메탈
# 7                         안예은                     댄스
# 8                         정동하                    발라드
# 9                    G-DRAGON                   랩/힙합
# 10                     Aimyon                  J-POP
# 11                        장덕철                    발라드
# 12                     Aimyon                  J-POP
# 13                        장덕철              발라드, 인디음악
# 14                        아이유                     댄스
# 15                     Aimyon                  J-POP
# 16                         신지                 댄스, 게임
# 17                       우주소녀                     댄스
# 18                        유승우              발라드, 인디음악
# 19          FTISLAND (FT아일랜드)                   록/메탈
# 20                        박세아                     게임
# 21                        코요태                   록/메탈
# 22                        장덕철                    발라드
# 23               태연 (TAEYEON)                    발라드
# 24                        김종서                   록/메탈
# 25                       July             랩/힙합, 인디음악
# 26                         경서                    발라드
# 27                    BIGBANG                    발라드
# 28                    BIGBANG                     댄스
# 29                    BIGBANG                     댄스
# 30                       July             랩/힙합, 인디음악
# 31                        아이유             발라드, 국내드라마
# 32                    BIGBANG               댄스, 랩/힙합
# 33                        성시경                    발라드
# 34                         거미                    발라드
# 35                        장범준                   록/메탈
# 36          백지영, 이홍기 (FT아일랜드)                    발라드
# 37                        장범준            록/메탈, 국내드라마
# 38               MSG워너비(정상동기)                    발라드
# 39                     Aimyon                  J-POP
# 40                     Aimyon                  J-POP
# 41            Ghost Town DJ's                    POP
# 42  Mandy Moore, Zachary Levi  POP, 애니메이션/웹툰, 키즈, 만화
# 43                    BIGBANG               댄스, 랩/힙합
# 44         Every Little Thing        애니메이션/웹툰, J-POP
# 45                        조수미             발라드, 국내드라마
# 46            Ghost Town DJ's               R&B/Soul

# %%
df.to_csv('myMusic.csv')
